# %%
import numpy as np

# %%
N=52000
header=4096
body=N-header

# header 4096

# %%
f = open('1MAD.ecd', "r")
a = np.fromfile(f, dtype=np.int16 , count=header )
b = np.fromfile(f, dtype=np.int16)
f.close()

# %%
a.shape,b.shape
# Out:
# ((4096,), (47904,))

# %%
body/16
# Out:
# 2994.0

# %%
b2=np.reshape(b,(int(len(b)/16),16)) #signo ordea las cosas columnas primero

# %%
b2.transpose()
# Out:
# array([[   231,    232,    231, ...,    206,    221,    125],
#        [   152,    152,    153, ...,    185,    183,    354],
#        [   137,    136,    137, ...,    139,    138,    179],
#        ...,
#        [-12615, -12722, -12621, ..., -12708, -12736, -12580],
#        [ 32709,  32710,  32710, ...,  32707,  32709,  32710],
#        [ 32711,  32710,  32708, ...,  32711,  32709,  32710]], dtype=int16)

# %%
b2.shape
# Out:
# (2994, 16)

# %%
h1=b2[:,0]
v1=b2[:,1]
h2=b2[:,2]
v2=b2[:,3]
h3=b2[:,4]
v3=b2[:,5]
h4=b2[:,6]
v4=b2[:,7]
h5=b2[:,8]
v5=b2[:,9]
h6=b2[:,10]
v6=b2[:,11]
h7=b2[:,12]
v7=b2[:,13]
h8=b2[:,14]
v8=b2[:,15]

# %%
import matplotlib.pyplot as plt

plt.plot(h1,v1,h2,v2,h3,v3,h4,v4,h5,v5,h6,v6,h7,v7,h8,v8)
plt.grid(True)

# %%
f = open('01001001.EI1', "r")
a = np.fromfile(f, dtype=np.int16 , count=header )
b = np.fromfile(f, dtype=np.int16)
f.close()

# %%
a.size
# Out:
# 4096

# %%
b.size
# Out:
# 68000

# %%
b.size/16
# Out:
# 4250.0

# %%
data48=np.reshape(b,(int(len(b)/16),16)) #signo ordea las cosas columnas primero

# %%
data48.shape
# Out:
# (4250, 16)

# %%
plt.plot(b3[:,0],b3[:,1])
plt.grid(True)

# %%
plt.plot(b3[:,2],b3[:,3])
plt.grid(True)

# %%
plt.plot(b3[:,4],b3[:,5])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 120268
f2 = open('.//CondU6SanNicSupCal101//DZSanNicSupC1 OBS F007C014I028.ecd', "r")
header = np.fromfile(f2, dtype=np.int8,count= 120268)
data = np.fromfile(f2, dtype=np.int8)
f2.close()

# %%
header.shape
# Out:
# (120268,)

# %%
ndata=data.shape[0]

# %%
ndata/8
# Out:
# 1181.0

# %%
N=64858

# %%
datalen=4*3*n

# %%
nheader=N-datalen

# %%
data=np.reshape(data,(1181,8)) #signo ordea las cosas columnas primero

# %%
data.shape
# Out:
# (1181, 8)

# %%
h1=data[:,0]
v1=data[:,1]
plt.plot(h1,v1,'o')
plt.grid(True)

# %%
h1=data[:,0]
v1=data[:,1]
h2=data[:,2]
v2=data[:,3]
h3=data[:,4]
v3=data[:,5]
h4=data[:,6]
v4=data[:,7]

# %%
plt.plot(h1,v1,h2,v2,h3,v3,h4,v4)
plt.grid(True)
