# %%
import pandas as pd

# %%
a=pd.read_csv('junta_seca.csv')
b=pd.read_csv('solda.csv')
c=pd.read_csv('squat.csv')

# %%
a.mean().plot()
# Out:
# <AxesSubplot:>

# %%
a.iloc[:,:-1].mean().plot()
# Out:
# <AxesSubplot:>

# %%
a.iloc[:50,:-1].T.plot(legend=False,color='k',alpha=0.1,figsize=[20,10],grid=True)
b.iloc[:50,:-1].T.plot(legend=False,color='c',alpha=0.1,figsize=[20,10],grid=True)
c.iloc[:50,:-1].T.plot(legend=False,color='m',alpha=0.1,figsize=[20,10],grid=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=[20,10])
plt.plot(a.iloc[:,:-1].mean().values)
plt.plot(b.iloc[:,:-1].mean().values)
plt.plot(c.iloc[:,:-1].mean().values)
plt.grid(True)

# %%
df=a.append(b).append(c)

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.085393  0.177870  0.154411  0.159484  0.149524  0.155847  0.158366
# 1     0.210573 -0.037309  0.025512 -0.011331  0.014510 -0.005077  0.004240
# 2     0.201934  0.436927  0.380968  0.402633  0.376700  0.396256  0.380134
# 3    -0.034340 -0.174999 -0.126797 -0.155137 -0.137420 -0.140366 -0.147482
# 4    -0.088975  0.135827  0.086117  0.120868  0.094929  0.120761  0.103652
# ...        ...       ...       ...       ...       ...       ...       ...
# 1025  0.316443  0.356502  0.332657  0.357391  0.364030  0.346921  0.339040
# 1026  0.673183  0.285418  0.335335  0.259904  0.283623  0.229529  0.264739
# 1027  0.626494  1.359393  1.177358  1.272297  1.169037  1.250667  1.185355
# 1028  0.110820 -0.498323 -0.343053 -0.414217 -0.361267 -0.391833 -0.358844
# 1029 -0.016223 -0.258241 -0.210531 -0.280619 -0.288666 -0.332547 -0.330876
#
# ...

# %%
import sklearn as sk

# %%
from sklearn.model_selection import train_test_split as split

# %%
x_train,x_test,y_train,y_test=split(df.iloc[:,:-1],df.TARGET)

# %%
x_train.shape
# Out:
# (2642, 1000)

# %%
x_test.shape
# Out:
# (881, 1000)

# %%
from sklearn.ensemble import ExtraTreesClassifier as xtree

# %%
model=xtree()

# %%
model.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, model.predict(x_test))
# Out:
# 0.9477866061293984

# %% [markdown]
# https://slundberg.github.io/shap/notebooks/deep_explainer/Front%20Page%20DeepExplainer%20MNIST%20Example.html
#
# https://slundberg.github.io/shap/notebooks/gradient_explainer/Explain%20an%20Intermediate%20Layer%20of%20VGG16%20on%20ImageNet.html
#
#
# https://www.researchgate.net/publication/348437966_A_Deep_Convolutional_Neural_Network_Method_to_Detect_Seizures_and_Characteristic_Frequencies_Using_Epileptic_Electroencephalogram_EEG_Data
